# %%
import csv
import re
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
def read_file(infile):
    myfile = open(infile,'r')
    readlen = []
    total = []
    for  row in myfile:
        line = row.split()
        readlen.append(line[1])
        total.append(line[0]) 
    return total, readlen

# %% [markdown]
# # Sample 701

# %%
#======501
total, readlen = read_file('SLX-17233.D701rna_D501rna.H3FYGBBXY.s_5.r_1_read_length.txt')

x = s1f1_readlen
y =[]
for i in range(0, len(total)): 
    y.append(float(total[i])/1)
BTtotal, BTreadlen = read_file('SLX-17233.D701rna_D501rna.H3FYGBBXY.s_5.r_1_read_length_before_trim.txt')

plt.bar(x,y)

for i in range(0, len(BTtotal)): 
    y.append(float(BTtotal[i])/1)
plt.bar(BTreadlen,y)
plt.title('Read Length Distribution')
plt.xlabel('Read Length')
plt.ylabel ('Total')
plt.savefig('s1f1.png')
plt.show()
plt.clf()
#=========502
total, readlen = read_file('SLX-17233.D701rna_D502rna.H3FYGBBXY.s_5.r_1_read_length.txt')

x = s1f1_readlen
y =[]
for i in range(0, len(total)): 
    y.append(float(total[i])/1)
BTtotal, BTreadlen = read_file('SLX-17233.D701rna_D502rna.H3FYGBBXY.s_5.r_1_read_length_before_trim.txt')

plt.bar(x,y)

for i in range(0, len(BTtotal)): 
    y.append(float(BTtotal[i])/1)
plt.bar(BTreadlen,y)
plt.title('HS1 Read Length Distribution')
plt.xlabel('Read Length')
plt.ylabel ('Total')
plt.savefig('s1f2.png')
plt.show()
plt.clf()
#=========503
total, readlen = read_file('SLX-17233.D701rna_D503rna.H3FYGBBXY.s_5.r_1_read_length.txt')

x = s1f1_readlen
y =[]
for i in range(0, len(total)): 
    y.append(float(total[i])/1)
BTtotal, BTreadlen = read_file('SLX-17233.D701rna_D503rna.H3FYGBBXY.s_5.r_1_read_length_before_trim.txt')

plt.bar(x,y)

for i in range(0, len(BTtotal)): 
    y.append(float(BTtotal[i])/1)
plt.bar(BTreadlen,y)
plt.title('HS2 Read Length Distribution')
plt.xlabel('Read Length')
plt.ylabel ('Total')
plt.savefig('s1f3.png')
plt.show()
plt.clf()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-81a39c4be857> in <module>()
#       2 total, readlen = read_file('SLX-17233.D701rna_D501rna.H3FYGBBXY.s_5.r_1_read_length.txt')
#       3
# ----> 4 x = s1f1_readlen
#       5 y =[]
#       6 for i in range(0, len(total)):
#
# NameError: name 's1f1_readlen' is not defined

# %% [markdown]
# # Sample 2

# %%
#======501
total, readlen = read_file('SLX-17233.D702rna_D501rna.H3FYGBBXY.s_5.r_1_read_length.txt')

x = s1f1_readlen
y =[]
for i in range(0, len(total)): 
    y.append(float(total[i])/1)
BTtotal, BTreadlen = read_file('SLX-17233.D702rna_D501rna.H3FYGBBXY.s_5.r_1_read_length_before_trim.txt')

plt.bar(x,y)

for i in range(0, len(BTtotal)): 
    y.append(float(BTtotal[i])/1)
plt.bar(BTreadlen,y)
plt.title('Read Length Distribution')
plt.xlabel('Read Length')
plt.ylabel ('Total')
plt.savefig('s2f1.png')
plt.show()
plt.clf()
#=========502
total, readlen = read_file('SLX-17233.D702rna_D502rna.H3FYGBBXY.s_5.r_1_read_length.txt')

x = readlen
y =[]
for i in range(0, len(total)): 
    y.append(float(total[i])/1)
BTtotal, BTreadlen = read_file('SLX-17233.D702rna_D502rna.H3FYGBBXY.s_5.r_1_read_length_before_trim.txt')

plt.bar(x,y)

for i in range(0, len(BTtotal)): 
    y.append(float(BTtotal[i])/1)
plt.bar(BTreadlen,y)
plt.title('HS1 Read Length Distribution')
plt.xlabel('Read Length')
plt.ylabel ('Total')
plt.savefig('s2f2.png')
plt.show()
plt.clf()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-6c8cbf2a3964> in <module>()
#       1 #======501
# ----> 2 total, readlen = read_file('SLX-17233.D702rna_D501rna.H3FYGBBXY.s_5.r_1_read_length.txt')
#       3
#       4 x = s1f1_readlen
#       5 y =[]
#
# NameError: name 'read_file' is not defined

# %% [markdown]
# # Sample 3

# %%
#======501
total, readlen = read_file('SLX-17233.D703rna_D501rna.H3FYGBBXY.s_5.r_1_read_length.txt')

x = s1f1_readlen
y =[]
for i in range(0, len(total)): 
    y.append(float(total[i])/1)
BTtotal, BTreadlen = read_file('SLX-17233.D703rna_D501rna.H3FYGBBXY.s_5.r_1_read_length_before_trim.txt')

plt.bar(x,y)

for i in range(0, len(BTtotal)): 
    y.append(float(BTtotal[i])/1)
plt.bar(BTreadlen,y)
plt.title('Read Length Distribution')
plt.xlabel('Read Length')
plt.ylabel ('Total')
plt.savefig('s3f1.png')
plt.show()
plt.clf()
#=========502
total, readlen = read_file('SLX-17233.D703rna_D502rna.H3FYGBBXY.s_5.r_1_read_length.txt')

x = s1f1_readlen
y =[]
for i in range(0, len(total)): 
    y.append(float(total[i])/1)
BTtotal, BTreadlen = read_file('SLX-17233.D703rna_D502rna.H3FYGBBXY.s_5.r_1_read_length_before_trim.txt')

plt.bar(x,y)

for i in range(0, len(BTtotal)): 
    y.append(float(BTtotal[i])/1)
plt.bar(BTreadlen,y)
plt.title('Read Length Distribution')
plt.xlabel('Read Length')
plt.ylabel ('Total')
plt.savefig('s3f2.png')
plt.show()
plt.clf()
#=========503
total, readlen = read_file('SLX-17233.D703rna_D503rna.H3FYGBBXY.s_5.r_1_read_length.txt')

x = s1f1_readlen
y =[]
for i in range(0, len(total)): 
    y.append(float(total[i])/1)
BTtotal, BTreadlen = read_file('SLX-17233.D703rna_D503rna.H3FYGBBXY.s_5.r_1_read_length_before_trim.txt')

plt.bar(x,y)

for i in range(0, len(BTtotal)): 
    y.append(float(BTtotal[i])/1)
plt.bar(BTreadlen,y)
plt.title('Read Length Distribution')
plt.xlabel('Read Length')
plt.ylabel ('Total')
plt.savefig('s3f3.png')
plt.show()
plt.clf()

# %% [markdown]
# # sample 4

# %%
#======501
total, readlen = read_file('SLX-17233.D704rna_D501rna.H3FYGBBXY.s_5.r_1_read_length.txt')

x = s1f1_readlen
y =[]
for i in range(0, len(total)): 
    y.append(float(total[i])/1)
BTtotal, BTreadlen = read_file('SLX-17233.D704rna_D501rna.H3FYGBBXY.s_5.r_1_read_length_before_trim.txt')

plt.bar(x,y)

for i in range(0, len(BTtotal)): 
    y.append(float(BTtotal[i])/1)
plt.bar(BTreadlen,y)
plt.title('Read Length Distribution')
plt.xlabel('Read Length')
plt.ylabel ('Total')
plt.savefig('s4f1.png')
plt.show()
plt.clf()
#=========502
total, readlen = read_file('SLX-17233.D704rna_D502rna.H3FYGBBXY.s_5.r_1_read_length.txt')

x = s1f1_readlen
y =[]
for i in range(0, len(total)): 
    y.append(float(total[i])/1)
BTtotal, BTreadlen = read_file('SLX-17233.D704rna_D502rna.H3FYGBBXY.s_5.r_1_read_length_before_trim.txt')

plt.bar(x,y)

for i in range(0, len(BTtotal)): 
    y.append(float(BTtotal[i])/1)
plt.bar(BTreadlen,y)
plt.title('Read Length Distribution')
plt.xlabel('Read Length')
plt.ylabel ('Total')
plt.savefig('s4f2.png')
plt.show()
plt.clf()
#=========503
total, readlen = read_file('SLX-17233.D704rna_D503rna.H3FYGBBXY.s_5.r_1_read_length.txt')

x = s1f1_readlen
y =[]
for i in range(0, len(total)): 
    y.append(float(total[i])/1)
BTtotal, BTreadlen = read_file('SLX-17233.D704rna_D503rna.H3FYGBBXY.s_5.r_1_read_length_before_trim.txt')

plt.bar(x,y)

for i in range(0, len(BTtotal)): 
    y.append(float(BTtotal[i])/1)
plt.bar(BTreadlen,y)
plt.title('Read Length Distribution')
plt.xlabel('Read Length')
plt.ylabel ('Total')
plt.savefig('s4f3.png')
plt.show()
plt.clf()

# %% [markdown]
# # Sample 5

# %%
#======501
total, readlen = read_file('SLX-17233.D705rna_D501rna.H3FYGBBXY.s_5.r_1_read_length.txt')

x = s1f1_readlen
y =[]
for i in range(0, len(total)): 
    y.append(float(total[i])/1)
BTtotal, BTreadlen = read_file('SLX-17233.D705rna_D501rna.H3FYGBBXY.s_5.r_1_read_length_before_trim.txt')

plt.bar(x,y)

for i in range(0, len(BTtotal)): 
    y.append(float(BTtotal[i])/1)
plt.bar(BTreadlen,y)
plt.title('Read Length Distribution')
plt.xlabel('Read Length')
plt.ylabel ('Total')
plt.savefig('s5f1.png')
plt.show()
plt.clf()
#=========502
total, readlen = read_file('SLX-17233.D705rna_D502rna.H3FYGBBXY.s_5.r_1_read_length.txt')

x = s1f1_readlen
y =[]
for i in range(0, len(total)): 
    y.append(float(total[i])/1)
BTtotal, BTreadlen = read_file('SLX-17233.D705rna_D502rna.H3FYGBBXY.s_5.r_1_read_length_before_trim.txt')

plt.bar(x,y)

for i in range(0, len(BTtotal)): 
    y.append(float(BTtotal[i])/1)
plt.bar(BTreadlen,y)
plt.title('Read Length Distribution')
plt.xlabel('Read Length')
plt.ylabel ('Total')
plt.savefig('s5f2.png')
plt.show()
plt.clf()
#=========503
total, readlen = read_file('SLX-17233.D705rna_D503rna.H3FYGBBXY.s_5.r_1_read_length.txt')

x = s1f1_readlen
y =[]
for i in range(0, len(total)): 
    y.append(float(total[i])/1)
BTtotal, BTreadlen = read_file('SLX-17233.D705rna_D503rna.H3FYGBBXY.s_5.r_1_read_length_before_trim.txt')

plt.bar(x,y)

for i in range(0, len(BTtotal)): 
    y.append(float(BTtotal[i])/1)
plt.bar(BTreadlen,y)
plt.title('Read Length Distribution')
plt.xlabel('Read Length')
plt.ylabel ('Total')
plt.savefig('s5f3.png')
plt.show()
plt.clf()

# %% [markdown]
# # Sample 6

# %%
#======501
total, readlen = read_file('SLX-17233.D706rna_D501rna.H3FYGBBXY.s_5.r_1_read_length.txt')

x = s1f1_readlen
y =[]
for i in range(0, len(total)): 
    y.append(float(total[i])/1)
BTtotal, BTreadlen = read_file('SLX-17233.D706rna_D501rna.H3FYGBBXY.s_5.r_1_read_length_before_trim.txt')

plt.bar(x,y)

for i in range(0, len(BTtotal)): 
    y.append(float(BTtotal[i])/1)
plt.bar(BTreadlen,y)
plt.title('Read Length Distribution')
plt.xlabel('Read Length')
plt.ylabel ('Total')
plt.savefig('s6f1.png')
plt.show()
plt.clf()
#=========502
total, readlen = read_file('SLX-17233.D706rna_D502rna.H3FYGBBXY.s_5.r_1_read_length.txt')

x = s1f1_readlen
y =[]
for i in range(0, len(total)): 
    y.append(float(total[i])/1)
BTtotal, BTreadlen = read_file('SLX-17233.D706rna_D502rna.H3FYGBBXY.s_5.r_1_read_length_before_trim.txt')

plt.bar(x,y)

for i in range(0, len(BTtotal)): 
    y.append(float(BTtotal[i])/1)
plt.bar(BTreadlen,y)
plt.title('Read Length Distribution')
plt.xlabel('Read Length')
plt.ylabel ('Total')
plt.savefig('s6f2.png')
plt.show()
plt.clf()
#=========503
total, readlen = read_file('SLX-17233.D706rna_D503rna.H3FYGBBXY.s_5.r_1_read_length.txt')

x = s1f1_readlen
y =[]
for i in range(0, len(total)): 
    y.append(float(total[i])/1)
BTtotal, BTreadlen = read_file('SLX-17233.D706rna_D503rna.H3FYGBBXY.s_5.r_1_read_length_before_trim.txt')

plt.bar(x,y)

for i in range(0, len(BTtotal)): 
    y.append(float(BTtotal[i])/1)
plt.bar(BTreadlen,y)
plt.title('Read Length Distribution')
plt.xlabel('Read Length')
plt.ylabel ('Total')
plt.savefig('s6f3.png')
plt.show()
plt.clf()

# %% [markdown]
# # Sample 7

# %%
#======501
total, readlen = read_file('SLX-17233.D707rna_D501rna.H3FYGBBXY.s_5.r_1_read_length.txt')

x = s1f1_readlen
y =[]
for i in range(0, len(total)): 
    y.append(float(total[i])/1)
BTtotal, BTreadlen = read_file('SLX-17233.D707rna_D501rna.H3FYGBBXY.s_5.r_1_read_length_before_trim.txt')

plt.bar(x,y)

for i in range(0, len(BTtotal)): 
    y.append(float(BTtotal[i])/1)
plt.bar(BTreadlen,y)
plt.title('Read Length Distribution')
plt.xlabel('Read Length')
plt.ylabel ('Total')
plt.savefig('s7f1.png')
plt.show()
plt.clf()
#=========502
total, readlen = read_file('SLX-17233.D707rna_D502rna.H3FYGBBXY.s_5.r_1_read_length.txt')

x = s1f1_readlen
y =[]
for i in range(0, len(total)): 
    y.append(float(total[i])/1)
BTtotal, BTreadlen = read_file('SLX-17233.D707rna_D502rna.H3FYGBBXY.s_5.r_1_read_length_before_trim.txt')

plt.bar(x,y)

for i in range(0, len(BTtotal)): 
    y.append(float(BTtotal[i])/1)
plt.bar(BTreadlen,y)
plt.title('Read Length Distribution')
plt.xlabel('Read Length')
plt.ylabel ('Total')
plt.savefig('s7f2.png')
plt.show()
plt.clf()
#=========503
total, readlen = read_file('SLX-17233.D707rna_D503rna.H3FYGBBXY.s_5.r_1_read_length.txt')

x = s1f1_readlen
y =[]
for i in range(0, len(total)): 
    y.append(float(total[i])/1)
BTtotal, BTreadlen = read_file('SLX-17233.D707rna_D503rna.H3FYGBBXY.s_5.r_1_read_length_before_trim.txt')

plt.bar(x,y)

for i in range(0, len(BTtotal)): 
    y.append(float(BTtotal[i])/1)
plt.bar(BTreadlen,y)
plt.title('Read Length Distribution')
plt.xlabel('Read Length')
plt.ylabel ('Total')
plt.savefig('s7f3.png')
plt.show()
plt.clf()

# %% [markdown]
# # Sample 8

# %%
#======501
total, readlen = read_file('SLX-17233.D708rna_D501rna.H3FYGBBXY.s_5.r_1_read_length.txt')

x = s1f1_readlen
y =[]
for i in range(0, len(total)): 
    y.append(float(total[i])/1)
BTtotal, BTreadlen = read_file('SLX-17233.D708rna_D501rna.H3FYGBBXY.s_5.r_1_read_length_before_trim.txt')

plt.bar(x,y)

for i in range(0, len(BTtotal)): 
    y.append(float(BTtotal[i])/1)
plt.bar(BTreadlen,y)
plt.title('Read Length Distribution')
plt.xlabel('Read Length')
plt.ylabel ('Total')
plt.savefig('s8f1.png')
plt.show()
plt.clf()
#=========502
total, readlen = read_file('SLX-17233.D708rna_D502rna.H3FYGBBXY.s_5.r_1_read_length.txt')

x = s1f1_readlen
y =[]
for i in range(0, len(total)): 
    y.append(float(total[i])/1)
BTtotal, BTreadlen = read_file('SLX-17233.D708rna_D502rna.H3FYGBBXY.s_5.r_1_read_length_before_trim.txt')

plt.bar(x,y)

for i in range(0, len(BTtotal)): 
    y.append(float(BTtotal[i])/1)
plt.bar(BTreadlen,y)
plt.title('Read Length Distribution')
plt.xlabel('Read Length')
plt.ylabel ('Total')
plt.savefig('s8f2.png')
plt.show()
plt.clf()
#=========503
total, readlen = read_file('SLX-17233.D708rna_D503rna.H3FYGBBXY.s_5.r_1_read_length.txt')

x = s1f1_readlen
y =[]
for i in range(0, len(total)): 
    y.append(float(total[i])/1)
BTtotal, BTreadlen = read_file('SLX-17233.D708rna_D503rna.H3FYGBBXY.s_5.r_1_read_length_before_trim.txt')

plt.bar(x,y)

for i in range(0, len(BTtotal)): 
    y.append(float(BTtotal[i])/1)
plt.bar(BTreadlen,y)
plt.title('Read Length Distribution')
plt.xlabel('Read Length')
plt.ylabel ('Total')
plt.savefig('s8f3.png')
plt.show()
plt.clf()

# %% [markdown]
# # Sample 9

# %%
#======501
total, readlen = read_file('SLX-17233.D709rna_D501rna.H3FYGBBXY.s_5.r_1_read_length.txt')

x = s1f1_readlen
y =[]
for i in range(0, len(total)): 
    y.append(float(total[i])/1)
BTtotal, BTreadlen = read_file('SLX-17233.D709rna_D501rna.H3FYGBBXY.s_5.r_1_read_length_before_trim.txt')

plt.bar(x,y)

for i in range(0, len(BTtotal)): 
    y.append(float(BTtotal[i])/1)
plt.bar(BTreadlen,y)
plt.title('Read Length Distribution')
plt.xlabel('Read Length')
plt.ylabel ('Total')
plt.savefig('s9f1.png')
plt.show()
plt.clf()
#=========502
total, readlen = read_file('SLX-17233.D709rna_D502rna.H3FYGBBXY.s_5.r_1_read_length.txt')

x = s1f1_readlen
y =[]
for i in range(0, len(total)): 
    y.append(float(total[i])/1)
BTtotal, BTreadlen = read_file('SLX-17233.D709rna_D502rna.H3FYGBBXY.s_5.r_1_read_length_before_trim.txt')

plt.bar(x,y)

for i in range(0, len(BTtotal)): 
    y.append(float(BTtotal[i])/1)
plt.bar(BTreadlen,y)
plt.title('Read Length Distribution')
plt.xlabel('Read Length')
plt.ylabel ('Total')
plt.savefig('s9f2.png')
plt.show()
plt.clf()
#=========503
total, readlen = read_file('SLX-17233.D709rna_D503rna.H3FYGBBXY.s_5.r_1_read_length.txt')

x = s1f1_readlen
y =[]
for i in range(0, len(total)): 
    y.append(float(total[i])/1)
BTtotal, BTreadlen = read_file('SLX-17233.D709rna_D503rna.H3FYGBBXY.s_5.r_1_read_length_before_trim.txt')

plt.bar(x,y)

for i in range(0, len(BTtotal)): 
    y.append(float(BTtotal[i])/1)
plt.bar(BTreadlen,y)
plt.title('Read Length Distribution')
plt.xlabel('Read Length')
plt.ylabel ('Total')
plt.savefig('s9f3.png')
plt.show()
plt.clf()

# %% [markdown]
# # Sample 10

# %%
#======501
total, readlen = read_file('SLX-17233.D710rna_D501rna.H3FYGBBXY.s_5.r_1_read_length.txt')

x = s1f1_readlen
y =[]
for i in range(0, len(total)): 
    y.append(float(total[i])/1)
BTtotal, BTreadlen = read_file('SLX-17233.D710rna_D501rna.H3FYGBBXY.s_5.r_1_read_length_before_trim.txt')

plt.bar(x,y)

for i in range(0, len(BTtotal)): 
    y.append(float(BTtotal[i])/1)
plt.bar(BTreadlen,y)
plt.title('Read Length Distribution')
plt.xlabel('Read Length')
plt.ylabel ('Total')
plt.savefig('s10f1.png')
plt.show()
plt.clf()
#=========502
total, readlen = read_file('SLX-17233.D710rna_D502rna.H3FYGBBXY.s_5.r_1_read_length.txt')

x = s1f1_readlen
y =[]
for i in range(0, len(total)): 
    y.append(float(total[i])/1)
BTtotal, BTreadlen = read_file('SLX-17233.D710rna_D502rna.H3FYGBBXY.s_5.r_1_read_length_before_trim.txt')

plt.bar(x,y)

for i in range(0, len(BTtotal)): 
    y.append(float(BTtotal[i])/1)
plt.bar(BTreadlen,y)
plt.title('Read Length Distribution')
plt.xlabel('Read Length')
plt.ylabel ('Total')
plt.savefig('s10f2.png')
plt.show()
plt.clf()
#=========503
total, readlen = read_file('SLX-17233.D710rna_D503rna.H3FYGBBXY.s_5.r_1_read_length.txt')

x = s1f1_readlen
y =[]
for i in range(0, len(total)): 
    y.append(float(total[i])/1)
BTtotal, BTreadlen = read_file('SLX-17233.D710rna_D503rna.H3FYGBBXY.s_5.r_1_read_length_before_trim.txt')

plt.bar(x,y)

for i in range(0, len(BTtotal)): 
    y.append(float(BTtotal[i])/1)
plt.bar(BTreadlen,y)
plt.title('Read Length Distribution')
plt.xlabel('Read Length')
plt.ylabel ('Total')
plt.savefig('s10f3.png')
plt.show()
plt.clf()

# %% [markdown]
# # Sample 711

# %%
#======501
total, readlen = read_file('SLX-17233.D711rna_D501rna.H3FYGBBXY.s_5.r_1_read_length.txt')

x = s1f1_readlen
y =[]
for i in range(0, len(total)): 
    y.append(float(total[i])/1)
BTtotal, BTreadlen = read_file('SLX-17233.D711rna_D501rna.H3FYGBBXY.s_5.r_1_read_length_before_trim.txt')

plt.bar(x,y)

for i in range(0, len(BTtotal)): 
    y.append(float(BTtotal[i])/1)
plt.bar(BTreadlen,y)
plt.title('Read Length Distribution')
plt.xlabel('Read Length')
plt.ylabel ('Total')
plt.savefig('s11f1.png')
plt.show()
plt.clf()
#=========502
total, readlen = read_file('SLX-17233.D711rna_D502rna.H3FYGBBXY.s_5.r_1_read_length.txt')

x = s1f1_readlen
y =[]
for i in range(0, len(total)): 
    y.append(float(total[i])/1)
BTtotal, BTreadlen = read_file('SLX-17233.D711rna_D502rna.H3FYGBBXY.s_5.r_1_read_length_before_trim.txt')

plt.bar(x,y)

for i in range(0, len(BTtotal)): 
    y.append(float(BTtotal[i])/1)
plt.bar(BTreadlen,y)
plt.title('Read Length Distribution')
plt.xlabel('Read Length')
plt.ylabel ('Total')
plt.savefig('s11f2.png')
plt.show()
plt.clf()
#=========503
total, readlen = read_file('SLX-17233.D711rna_D503rna.H3FYGBBXY.s_5.r_1_read_length.txt')

x = s1f1_readlen
y =[]
for i in range(0, len(total)): 
    y.append(float(total[i])/1)
BTtotal, BTreadlen = read_file('SLX-17233.D711rna_D503rna.H3FYGBBXY.s_5.r_1_read_length_before_trim.txt')

plt.bar(x,y)

for i in range(0, len(BTtotal)): 
    y.append(float(BTtotal[i])/1)
plt.bar(BTreadlen,y)
plt.title('Read Length Distribution')
plt.xlabel('Read Length')
plt.ylabel ('Total')
plt.savefig('s11f3.png')
plt.show()
plt.clf()

# %% [markdown]
# # Sample 12

# %%
#======501
total, readlen = read_file('SLX-17233.D712rna_D501rna.H3FYGBBXY.s_5.r_1_read_length.txt')

x = s1f1_readlen
y =[]
for i in range(0, len(total)): 
    y.append(float(total[i])/1)
BTtotal, BTreadlen = read_file('SLX-17233.D712rna_D501rna.H3FYGBBXY.s_5.r_1_read_length_before_trim.txt')

plt.bar(x,y)

for i in range(0, len(BTtotal)): 
    y.append(float(BTtotal[i])/1)
plt.bar(BTreadlen,y)
plt.title('Read Length Distribution')
plt.xlabel('Read Length')
plt.ylabel ('Total')
plt.savefig('s12f1.png')
plt.show()
plt.clf()
#=========502
total, readlen = read_file('SLX-17233.D712rna_D502rna.H3FYGBBXY.s_5.r_1_read_length.txt')

x = s1f1_readlen
y =[]
for i in range(0, len(total)): 
    y.append(float(total[i])/1)
BTtotal, BTreadlen = read_file('SLX-17233.D712rna_D502rna.H3FYGBBXY.s_5.r_1_read_length_before_trim.txt')

plt.bar(x,y)

for i in range(0, len(BTtotal)): 
    y.append(float(BTtotal[i])/1)
plt.bar(BTreadlen,y)
plt.title('Read Length Distribution')
plt.xlabel('Read Length')
plt.ylabel ('Total')
plt.savefig('s12f2.png')
plt.show()
plt.clf()
